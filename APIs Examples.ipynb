# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
response = requests.get("https://official-joke-api.appspot.com/random_joke")
Randomjoke = response.json()
print(Randomjoke)
print(len(Randomjoke))
# Out:
# {'id': 321, 'type': 'general', 'setup': 'Why can\'t you use "Beef stew"as a password?', 'punchline': "Because it's not stroganoff."}
# 4

# %%
for i in Randomjoke:
    print(i)
# Out:
# id
# type
# setup
# punchline

# %%
print(Randomjoke['type'])
print(len(Randomjoke['type']))
# Out:
# general
# 7

# %%
import requests
response = requests.get("https://api.coindesk.com/v1/bpi/currentprice.json")
CurrentPrice = response.json()
print(CurrentPrice)
print(len(CurrentPrice))
# Out:
# {'time': {'updated': 'Jun 27, 2021 06:41:00 UTC', 'updatedISO': '2021-06-27T06:41:00+00:00', 'updateduk': 'Jun 27, 2021 at 07:41 BST'}, 'disclaimer': 'This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org', 'chartName': 'Bitcoin', 'bpi': {'USD': {'code': 'USD', 'symbol': '&#36;', 'rate': '32,975.8619', 'description': 'United States Dollar', 'rate_float': 32975.8619}, 'GBP': {'code': 'GBP', 'symbol': '&pound;', 'rate': '23,751.7549', 'description': 'British Pound Sterling', 'rate_float': 23751.7549}, 'EUR': {'code': 'EUR', 'symbol': '&euro;', 'rate': '27,627.0122', 'description': 'Euro', 'rate_float': 27627.0122}}}
# 4

# %%
for i in CurrentPrice:
    print(i)
# Out:
# time
# disclaimer
# chartName
# bpi

# %%
print(CurrentPrice['time'])
print(len(CurrentPrice['time']))
# Out:
# {'updated': 'Jun 27, 2021 06:41:00 UTC', 'updatedISO': '2021-06-27T06:41:00+00:00', 'updateduk': 'Jun 27, 2021 at 07:41 BST'}
# 3

# %%
import requests
response = requests.get("https://datausa.io/api/data?drilldowns=Nation&measures=Population")
PopulationUSA = response.json()
print(PopulationUSA)
print(len(PopulationUSA))
# Out:
# {'data': [{'ID Nation': '01000US', 'Nation': 'United States', 'ID Year': 2018, 'Year': '2018', 'Population': 327167439, 'Slug Nation': 'united-states'}, {'ID Nation': '01000US', 'Nation': 'United States', 'ID Year': 2017, 'Year': '2017', 'Population': 325719178, 'Slug Nation': 'united-states'}, {'ID Nation': '01000US', 'Nation': 'United States', 'ID Year': 2016, 'Year': '2016', 'Population': 323127515, 'Slug Nation': 'united-states'}, {'ID Nation': '01000US', 'Nation': 'United States', 'ID Year': 2015, 'Year': '2015', 'Population': 321418821, 'Slug Nation': 'united-states'}, {'ID Nation': '01000US', 'Nation': 'United States', 'ID Year': 2014, 'Year': '2014', 'Population': 318857056, 'Slug Nation': 'united-states'}, {'ID Nation': '01000US', 'Nation': 'United States', 'ID Year': 2013, 'Year': '2013', 'Population': 316128839, 'Slug Nation': 'united-states'}], 'source': [{'measures': ['Population'], 'annotations': {'source_name': 'Census Bureau', 'source_description': 'The American Commu
# ...

# %%
for i in PopulationUSA:
    print(i)
# Out:
# data
# source

# %%
print(PopulationUSA['source'])
print(len(PopulationUSA['source']))
# Out:
# [{'measures': ['Population'], 'annotations': {'source_name': 'Census Bureau', 'source_description': 'The American Community Survey (ACS) is conducted by the US Census and sent to a portion of the population every year.', 'dataset_name': 'ACS 1-year Estimate', 'dataset_link': 'http://www.census.gov/programs-surveys/acs/', 'table_id': 'B01003', 'topic': 'Diversity', 'subtopic': 'Demographics'}, 'name': 'acs_yg_total_population_1', 'substitutions': []}]
# 1

# %%
import requests
response = requests.get("https://www.boredapi.com/api/activity")
Boredapi = response.json()
print(Boredapi)
print(len(Boredapi))
# Out:
# {'activity': "Clean out your closet and donate the clothes you've outgrown", 'type': 'charity', 'participants': 1, 'price': 0, 'link': '', 'key': '9026787', 'accessibility': 0.1}
# 7

# %%
for i in Boredapi:
    print(i)
# Out:
# activity
# type
# participants
# price
# link
# key
# accessibility

# %%
print(Boredapi['key'])
print(len(Boredapi['key']))
# Out:
# 9026787
# 7

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
response = requests.get("http://api.covid19india.org/data.json")
coviddata = response.json()
print(coviddata)
print(len(coviddata))
# Out:
# {'cases_time_series': [{'dailyconfirmed': '1', 'dailydeceased': '0', 'dailyrecovered': '0', 'date': '30 January 2020', 'dateymd': '2020-01-30', 'totalconfirmed': '1', 'totaldeceased': '0', 'totalrecovered': '0'}, {'dailyconfirmed': '0', 'dailydeceased': '0', 'dailyrecovered': '0', 'date': '31 January 2020', 'dateymd': '2020-01-31', 'totalconfirmed': '1', 'totaldeceased': '0', 'totalrecovered': '0'}, {'dailyconfirmed': '0', 'dailydeceased': '0', 'dailyrecovered': '0', 'date': '1 February 2020', 'dateymd': '2020-02-01', 'totalconfirmed': '1', 'totaldeceased': '0', 'totalrecovered': '0'}, {'dailyconfirmed': '1', 'dailydeceased': '0', 'dailyrecovered': '0', 'date': '2 February 2020', 'dateymd': '2020-02-02', 'totalconfirmed': '2', 'totaldeceased': '0', 'totalrecovered': '0'}, {'dailyconfirmed': '1', 'dailydeceased': '0', 'dailyrecovered': '0', 'date': '3 February 2020', 'dateymd': '2020-02-03', 'totalconfirmed': '3', 'totaldeceased': '0', 'totalrecovered': '0'}, {'dailyconfirmed': '0', '
# ...

# %%
for i in coviddata:
  print(i)
# Out:
# cases_time_series
# statewise
# tested

# %%
print(coviddata['statewise'])
print(len(coviddata['statewise']))
# Out:
# [{'active': '559483', 'confirmed': '30291751', 'deaths': '397136', 'deltaconfirmed': '12765', 'deltadeaths': '375', 'deltarecovered': '21014', 'lastupdatedtime': '28/06/2021 19:49:04', 'migratedother': '11895', 'recovered': '29323237', 'state': 'Total', 'statecode': 'TT', 'statenotes': ''}, {'active': '62', 'confirmed': '7455', 'deaths': '127', 'deltaconfirmed': '0', 'deltadeaths': '0', 'deltarecovered': '0', 'lastupdatedtime': '27/06/2021 19:55:08', 'migratedother': '0', 'recovered': '7266', 'state': 'Andaman and Nicobar Islands', 'statecode': 'AN', 'statenotes': ''}, {'active': '42252', 'confirmed': '1882096', 'deaths': '12630', 'deltaconfirmed': '2224', 'deltadeaths': '31', 'deltarecovered': '4714', 'lastupdatedtime': '28/06/2021 18:19:08', 'migratedother': '0', 'recovered': '1827214', 'state': 'Andhra Pradesh', 'statecode': 'AP', 'statenotes': ''}, {'active': '2495', 'confirmed': '34932', 'deaths': '167', 'deltaconfirmed': '0', 'deltadeaths': '0', 'deltarecovered': '0', 'lastupda
# ...

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
response = requests.get("http://chess-api-chess.herokuapp.com/api/v1/scoreboard")
chessscore = response.json()
print(chessscore)
print(len(chessscore))
# Out:
# {'status': 'Scoreboard created!', '_id': '60def2b6d9866100146589a3'}
# 2

# %%
for i in chessscore:
  print(i)
# Out:
# status
# _id

# %%
print(chessscore['status'])
print(len(chessscore['status']))
# Out:
# Scoreboard created!
# 19

# %%
pip install chess
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# import required module
import chess
  
# create board object
board=chess.Board()
  
# display chess board
print(board)
# Out:
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R

# %%
# legal moves
board.legal_moves
# Out:
# <LegalMoveGenerator at 0x29195268970 (Nh3, Nf3, Nc3, Na3, h3, g3, f3, e3, d3, c3, b3, a3, h4, g4, f4, e4, d4, c4, b4, a4)>

# %%
# moving players
board.push_san("e3")
# It means moving the particlular piece at 
# e place to 4th postion 
   
# Display chess board  
print(board)
# Out:
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . P . . .
# P P P P . P P P
# R N B Q K B N R

# %%
import requests
response = requests.get("https://api.chess.com/context/Player.jsonld")
chessinfo = response.json()
print(chessinfo)
# Out:
# {'@context': {'Player': 'http://json-ld.org/contexts/person.jsonld', 'xsd': 'http://www.w3.org/2001/XMLSchema#', 'avatar': {'@id': 'http://xmlns.com/foaf/0.1/img', '@type': '@id'}, 'username': {'@id': 'http://xmlns.com/foaf/0.1/nick', '@type': '@id'}, 'location': {'@id': 'http://schema.org/URL', '@type': '@id'}, 'name': {'@id': 'http://xmlns.com/foaf/0.1/givenName', '@type': '@id'}, 'last_online': {'@id': 'http://schema.org/Integer', '@type': '@id'}, 'joined': {'@id': 'http://schema.org/Integer', '@type': '@id'}, 'country': {'@id': 'https://api.chess.com/context/Country', '@type': '@id'}, 'status': {'@id': 'http://schema.org/Text', '@type': '@id'}}}

# %%
for i in chessinfo:
    print(i)
# Out:
# @context

# %%
print(chessinfo['@context'])
# Out:
# {'Player': 'http://json-ld.org/contexts/person.jsonld', 'xsd': 'http://www.w3.org/2001/XMLSchema#', 'avatar': {'@id': 'http://xmlns.com/foaf/0.1/img', '@type': '@id'}, 'username': {'@id': 'http://xmlns.com/foaf/0.1/nick', '@type': '@id'}, 'location': {'@id': 'http://schema.org/URL', '@type': '@id'}, 'name': {'@id': 'http://xmlns.com/foaf/0.1/givenName', '@type': '@id'}, 'last_online': {'@id': 'http://schema.org/Integer', '@type': '@id'}, 'joined': {'@id': 'http://schema.org/Integer', '@type': '@id'}, 'country': {'@id': 'https://api.chess.com/context/Country', '@type': '@id'}, 'status': {'@id': 'http://schema.org/Text', '@type': '@id'}}

# %%
import requests
response = requests.get("https://api.chess.com/pub/titled/GM")
chess_info = response.json()
print(chess_info)
# Out:
# {'players': ['123lt', '124chess', '1977ivan', '1stsecond', '4thd-alpeacefulmoon', '64aramis64', '64arthos64', '64atilla64', '64dartagnan64', '64genghis64', '64leonidas64', '64porthos64', '64pyrrhus64', '731291', 'a-adly', 'a-fier', 'abasovn', 'abhidabhi', 'abhijeetgupta', 'abhijeetgupta1016', 'abhijeetonyoutube', 'abhyak', 'abykhovsky', 'actorxu', 'adaro', 'adham_fawzy', 'adiosabu', 'afgano29', 'aggy67', 'agser', 'airgun1', 'aivanov-ne', 'akobian-sea', 'akobian-stl', 'akshatchandra', 'akshayraj_kore', 'aleksa74', 'aleksandrovaleksei', 'alexander-evdokimov', 'alexanderl', 'alexander_donchenko', 'alexander_moskalenko', 'alexander_zubov', 'alexandr_predke', 'alexchess1062', 'alexchess1984', 'alexcolovic', 'alexeishirov', 'alexhuzman', 'alexonischuk', 'alexrustemov', 'alexsur1981', 'alexvangog', 'alexyermo', 'alex_goloshchapov', 'alex_stripunsky', 'algeriano22', 'allanstig', 'almo64', 'alphaodin', 'amintabatabaei', 'amirbagheri78', 'amirreza_p', 'anaconda1983', 'anand', 'andabata', 'andr
# ...

# %%
for i in chess_info:
    print(i)
# Out:
# players

# %%
print(chess_info['players'])
# Out:
# ['123lt', '124chess', '1977ivan', '1stsecond', '4thd-alpeacefulmoon', '64aramis64', '64arthos64', '64atilla64', '64dartagnan64', '64genghis64', '64leonidas64', '64porthos64', '64pyrrhus64', '731291', 'a-adly', 'a-fier', 'abasovn', 'abhidabhi', 'abhijeetgupta', 'abhijeetgupta1016', 'abhijeetonyoutube', 'abhyak', 'abykhovsky', 'actorxu', 'adaro', 'adham_fawzy', 'adiosabu', 'afgano29', 'aggy67', 'agser', 'airgun1', 'aivanov-ne', 'akobian-sea', 'akobian-stl', 'akshatchandra', 'akshayraj_kore', 'aleksa74', 'aleksandrovaleksei', 'alexander-evdokimov', 'alexanderl', 'alexander_donchenko', 'alexander_moskalenko', 'alexander_zubov', 'alexandr_predke', 'alexchess1062', 'alexchess1984', 'alexcolovic', 'alexeishirov', 'alexhuzman', 'alexonischuk', 'alexrustemov', 'alexsur1981', 'alexvangog', 'alexyermo', 'alex_goloshchapov', 'alex_stripunsky', 'algeriano22', 'allanstig', 'almo64', 'alphaodin', 'amintabatabaei', 'amirbagheri78', 'amirreza_p', 'anaconda1983', 'anand', 'andabata', 'andrbaryshpolets
# ...

# %%
import requests
response = requests.get("https://api.chess.com/pub/player/erik/stats")
chess_info = response.json()
print(chess_info)
# Out:
# {'chess_daily': {'last': {'rating': 1573, 'date': 1624590786, 'rd': 59}, 'best': {'rating': 2065, 'date': 1256228875, 'game': 'https://www.chess.com/game/daily/26087202'}, 'record': {'win': 2508, 'loss': 1609, 'draw': 303, 'time_per_move': 14837, 'timeout_percent': 0}, 'tournament': {'points': 76, 'withdraw': 1, 'count': 1, 'highest_finish': 1}}, 'chess960_daily': {'last': {'rating': 1487, 'date': 1624315300, 'rd': 75}, 'best': {'rating': 1779, 'date': 1466772304, 'game': 'https://www.chess.com/game/daily/155362414'}, 'record': {'win': 288, 'loss': 174, 'draw': 23, 'time_per_move': 14837, 'timeout_percent': 0}, 'tournament': {'points': 76, 'withdraw': 1, 'count': 1, 'highest_finish': 1}}, 'chess_rapid': {'last': {'rating': 1485, 'date': 1554249860, 'rd': 100}, 'best': {'rating': 1613, 'date': 1471203395, 'game': 'https://www.chess.com/game/live/758005361'}, 'record': {'win': 9, 'loss': 6, 'draw': 0}}, 'chess_bullet': {'last': {'rating': 1591, 'date': 1625200599, 'rd': 37}, 'best': {'
# ...

# %%
for i in chess_info:
    print(i)
# Out:
# chess_daily
# chess960_daily
# chess_rapid
# chess_bullet
# chess_blitz
# fide
# tactics
# lessons
# puzzle_rush

# %%
print(chess_info['chess_rapid'])
# Out:
# {'last': {'rating': 1485, 'date': 1554249860, 'rd': 100}, 'best': {'rating': 1613, 'date': 1471203395, 'game': 'https://www.chess.com/game/live/758005361'}, 'record': {'win': 9, 'loss': 6, 'draw': 0}}

# %%
import requests
response = requests.get("https://api.chess.com/pub/player/erik/tournaments")
chess_info = response.json()
print(chess_info)
# Out:
# {'finished': [{'url': 'https://www.chess.com/tournament/100-years-of-chemotherapy---remembrance-tournament', '@id': 'https://api.chess.com/pub/tournament/100-years-of-chemotherapy---remembrance-tournament', 'wins': 11, 'losses': 5, 'draws': 0, 'points_awarded': 31, 'placement': 10, 'status': 'eliminated', 'total_players': 100}, {'url': 'https://www.chess.com/tournament/10th-chesscom-quick-knockouts-1801-2000', '@id': 'https://api.chess.com/pub/tournament/10th-chesscom-quick-knockouts-1801-2000', 'wins': 2, 'losses': 7, 'draws': 1, 'points_awarded': 0, 'placement': 159, 'status': 'eliminated', 'total_players': 210}, {'url': 'https://www.chess.com/tournament/10th-chesscom-thematic-tournament---caro-kann-1601-1800', '@id': 'https://api.chess.com/pub/tournament/10th-chesscom-thematic-tournament---caro-kann-1601-1800', 'wins': 14, 'losses': 5, 'draws': 1, 'points_awarded': 49, 'placement': 27, 'status': 'eliminated', 'total_players': 711}, {'url': 'https://www.chess.com/tournament/10th-ch
# ...

# %%
for i in chess_info:
    print(i)
# Out:
# finished
# in_progress
# registered

# %%
print(chess_info['in_progress'])
# Out:
# [{'url': 'https://www.chess.com/tournament/chess-com-staff-chess960-tournament-2020', '@id': 'https://api.chess.com/pub/tournament/chess-com-staff-chess960-tournament-2020', 'wins': 5, 'losses': 9, 'draws': 0, 'status': 'eliminated', 'total_players': 67}, {'url': 'https://www.chess.com/tournament/chess-com-staff-tournament-2021', '@id': 'https://api.chess.com/pub/tournament/chess-com-staff-tournament-2021', 'wins': 8, 'losses': 5, 'draws': 1, 'status': 'eliminated', 'total_players': 96}, {'url': 'https://www.chess.com/tournament/chess-com-staff-tournament-2019', '@id': 'https://api.chess.com/pub/tournament/chess-com-staff-tournament-2019', 'wins': 3, 'losses': 7, 'draws': 2, 'status': 'eliminated', 'total_players': 65}, {'url': 'https://www.chess.com/tournament/chess-com-staff-tournament-may-2016', '@id': 'https://api.chess.com/pub/tournament/chess-com-staff-tournament-may-2016', 'wins': 9, 'losses': 7, 'draws': 2, 'status': 'eliminated', 'total_players': 69}]

# %%
import requests
response = requests.get("https://api.chess.com/pub/club/chess-com-developer-community/members")
chessinfo = response.json()
print(chessinfo)
# Out:
# {'weekly': [{'username': '1badbluepenguine', 'joined': 1617359906}, {'username': '7ania7', 'joined': 1573317101}, {'username': 'aayamshrestha555', 'joined': 1620126205}, {'username': 'abd_farzin', 'joined': 1511375617}, {'username': 'abhinav0121', 'joined': 1600314771}, {'username': 'adamraichu', 'joined': 1619464675}, {'username': 'aidan-smith', 'joined': 1596653385}, {'username': 'aleksandr19962017', 'joined': 1524244923}, {'username': 'alenbasic', 'joined': 1622694263}, {'username': 'alexander30', 'joined': 1614934777}, {'username': 'alphasingh', 'joined': 1603761394}, {'username': 'alsmirn', 'joined': 1624550173}, {'username': 'andreamorandini', 'joined': 1500311511}, {'username': 'andrejsusnik', 'joined': 1621191345}, {'username': 'aneshsaravanan', 'joined': 1624968554}, {'username': 'apistotelhs', 'joined': 1588194582}, {'username': 'arasub', 'joined': 1609656194}, {'username': 'ari3645', 'joined': 1625217373}, {'username': 'arkangel75_ar', 'joined': 1612274672}, {'username': '
# ...

# %%
for i in chessinfo:
    print(i)
# Out:
# weekly
# monthly
# all_time

# %%
print(chessinfo['weekly'])
# Out:
# [{'username': '1badbluepenguine', 'joined': 1617359906}, {'username': '7ania7', 'joined': 1573317101}, {'username': 'aayamshrestha555', 'joined': 1620126205}, {'username': 'abd_farzin', 'joined': 1511375617}, {'username': 'abhinav0121', 'joined': 1600314771}, {'username': 'adamraichu', 'joined': 1619464675}, {'username': 'aidan-smith', 'joined': 1596653385}, {'username': 'aleksandr19962017', 'joined': 1524244923}, {'username': 'alenbasic', 'joined': 1622694263}, {'username': 'alexander30', 'joined': 1614934777}, {'username': 'alphasingh', 'joined': 1603761394}, {'username': 'alsmirn', 'joined': 1624550173}, {'username': 'andreamorandini', 'joined': 1500311511}, {'username': 'andrejsusnik', 'joined': 1621191345}, {'username': 'aneshsaravanan', 'joined': 1624968554}, {'username': 'apistotelhs', 'joined': 1588194582}, {'username': 'arasub', 'joined': 1609656194}, {'username': 'ari3645', 'joined': 1625217373}, {'username': 'arkangel75_ar', 'joined': 1612274672}, {'username': 'arkustrew',
# ...
